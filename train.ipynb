# %%
# %cd /content/drive/MyDrive/dentalProjectFinal
# Out:
# /content/drive/MyDrive/dentalProjectFinal

# %%
# !pip install roboflow

# from roboflow import Roboflow
# rf = Roboflow(api_key="l1o8GkYU1NyjHDLnmP8R")
# project = rf.workspace("arihant").project("dental-project-2")
# version = project.version(2)
# dataset = version.download("yolov8")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.9/86.9 kB 3.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 7.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 21.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 57.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 107.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.12.0.88
#     Uninstalling opencv-python-headless-4.12.0.88:
#       Successfully uninstalled opencv-python-headless-4.12.0.88
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Dental-Project-2-2 in yolov8:: 100%|██████████| 528/528 [00:05<00:00, 98.31it/s]

# %%
# !pip -q install ultralytics
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 55.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 107.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 78.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 50.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 14.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 68.1 MB/s eta 0:00:00

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")
model.info()
results = model.train(
    data="/content/drive/MyDrive/dentalProjectFinal/Dental-Project-2-2/data.yaml",
    epochs=50,
    imgsz=640
)

# Run inference on a sample image (update the path accordingly)
results = model("/content/drive/MyDrive/dentalProjectFinal/Dental-Project-2-2/train/images/image-100_jpg.rf.54647317f011817fb28f068a9895e1ca.jpg")
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# YOLOv8n summary: 129 layers, 3,157,200 parameters, 0 gradients, 8.9 GFLOPs
# Ultralytics 8.3.174 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
results = model.predict(source="/content/drive/MyDrive/dentalProjectFinal/Dental-Project-2-2/train/images/image-100_jpg.rf.54647317f011817fb28f068a9895e1ca.jpg", save=True, show=True)

# %%
# !pip -q install ultralytics

# %%
from ultralytics import YOLO

# %%
model = YOLO("/content/drive/MyDrive/dentalProjectFinal/runs/detect/train/weights/best.pt")

# %%
results = model.predict(source="/content/drive/MyDrive/dentalProjectFinal/Dental-Project-2-2/train/images/image-100_jpg.rf.54647317f011817fb28f068a9895e1ca.jpg", save=True, show=True)
# Out:
# WARNING ⚠️ Environment does not support cv2.imshow() or PIL Image.show()
#
#
# image 1/1 /content/drive/MyDrive/dentalProjectFinal/Dental-Project-2-2/train/images/image-100_jpg.rf.54647317f011817fb28f068a9895e1ca.jpg: 512x640 6 Permanent teeths, 6 Teethss, 35.1ms
# Speed: 3.9ms preprocess, 35.1ms inference, 164.1ms postprocess per image at shape (1, 3, 512, 640)
# Results saved to runs/detect/predict
